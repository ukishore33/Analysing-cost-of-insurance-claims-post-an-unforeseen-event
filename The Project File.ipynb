# %% [markdown]
# <a href="https://colab.research.google.com/github/ukishore33/Analysing-cost-of-insurance-claims-post-an-unforeseen-event/blob/main/The%20Project%20File.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
a=pd.read_csv('test.csv')

# %%
a.describe()
# Out:
#                   id          cont1          cont2          cont3  \
# count  125546.000000  125546.000000  125546.000000  125546.000000
# mean   294067.153442       0.494447       0.506939       0.498255
# std    170098.335649       0.187961       0.206837       0.201746
# min         4.000000       0.000016       0.001149       0.002634
# 25%    146414.250000       0.347403       0.358319       0.336963
# 50%    294306.000000       0.475784       0.555782       0.527991
# 75%    441800.000000       0.626630       0.681761       0.634224
# max    587634.000000       0.984975       0.862654       0.944251
#
#                cont4          cont5          cont6          cont7  \
# count  125546.000000  125546.000000  125546.000000  125546.000000
# mean        0.492334       0.487640       0.492188       0.485945
# std         0.210815       0.209119       0.205574       0.178650
# min         0.176921       0.281143       0.012683       0.069503
# ...

# %%
a.nunique()
# Out:
# id        125546
# cat1           2
# cat2           2
# cat3           2
# cat4           2
#            ...
# cont10       169
# cont11       314
# cont12       315
# cont13       355
# cont14     16673
# Length: 131, dtype: int64

# %%
a.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-ab22e0de5184> in <cell line: 1>()
# ----> 1 a.isnull(130).sum()
#
# TypeError: DataFrame.isnull() takes 1 positional argument but 2 were given

# %%
for c in a.columns:
  print('----%s----' % c)
  print(a[c].value_counts())
# Out:
# ----id----
# 4         1
# 392788    1
# 392782    1
# 392766    1
# 392764    1
#          ..
# 195320    1
# 195316    1
# 195313    1
# 195305    1
# 587634    1
# Name: id, Length: 125546, dtype: int64
# ----cat1----
# A    94096
# B    31450
# Name: cat1, dtype: int64
# ----cat2----
# A    71203
# B    54343
# Name: cat2, dtype: int64
# ----cat3----
# A    118752
# B      6794
# Name: cat3, dtype: int64
# ----cat4----
# A    86026
# B    39520
# Name: cat4, dtype: int64
# ----cat5----
# A    82282
# B    43264
# Name: cat5, dtype: int64
# ----cat6----
# A    88014
# B    37532
# Name: cat6, dtype: int64
# ----cat7----
# A    122546
# B      3000
# Name: cat7, dtype: int64
# ----cat8----
# A    118112
# B      7434
# Name: cat8, dtype: int64
# ----cat9----
# A    75509
# B    50037
# Name: cat9, dtype: int64
# ----cat10----
# A    106944
# B     18602
# Name: cat10, dtype: int64
# ----cat11----
# A    112470
# B     13076
# Name: cat11, dtype: int64
# ----cat12----
# A    106777
# ...
